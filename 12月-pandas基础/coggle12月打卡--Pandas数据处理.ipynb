# %% [markdown]
# ## 任务1：Pandas数据读取、保存和数据类型
# 任务要点：文件读取、保存、数据类型分析步骤
# 1. 读取文件https://cdn.coggle.club/Pokemon.csv
# 2. 将读取的进行保存，表头也需要保存
# 3. 分析每列的类型，取值个数
# 4. 分析每列是否包含缺失值

# %%
# 读取数据

import pandas as pd 
import numpy as np


df = pd.read_csv('https://cdn.coggle.club/Pokemon.csv')
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# 分析每列的类型，取值个数
df.dtypes
# Out:
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# Nidoran_             2
# Pidgeotto            1
# AggronMega Aggron    1
# Furfrou              1
# Jynx                 1
#                     ..
# Smoochum             1
# Seismitoad           1
# Swablu               1
# Blitzle              1
# Reshiram             1
# Name: Name, Length: 799, dtype: int64
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Rock        14
# Ghost       14
# Ice         14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# ...

# %%
# 分析每列是否包含缺失值

# df.sum ,默认axis=0，按列求和
df.isna().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
# 一个专门的可视化缺失值库 missingno，比较方便

import missingno as msno

msno.bar(df)

# %% [markdown]
# ## 任务2：Pandas数据位置索引任务要点：数据选择、数据索引
# - 步骤1：读取文件https://cdn.coggle.club/Pokemon.csv
# - 步骤2：选择出Total列
# - 步骤3：选择出Total列和HP列
# - 步骤4：选择出第10-40行数据
# - 步骤5：选择出第10-40行的Total列和HP列

# %%
df2 = pd.read_csv('https://cdn.coggle.club/Pokemon.csv')

df2['Total']
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: Total, Length: 800, dtype: int64

# %%
df[['Total','HP']]
# Out:
#      Total  HP
# 0      318  45
# 1      405  60
# 2      525  80
# 3      625  80
# 4      309  39
# ..     ...  ..
# 795    600  50
# 796    700  50
# 797    600  80
# 798    680  80
# 799    600  80
#
# [800 rows x 2 columns]

# %%
df2.loc[9:40,:]
# Out:
#                        Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 9                  Squirtle     Water     NaN    314  44      48       65
# 10                Wartortle     Water     NaN    405  59      63       80
# 11                Blastoise     Water     NaN    530  79      83      100
# 12  BlastoiseMega Blastoise     Water     NaN    630  79     103      120
# 13                 Caterpie       Bug     NaN    195  45      30       35
# 14                  Metapod       Bug     NaN    205  50      20       55
# 15               Butterfree       Bug  Flying    395  60      45       50
# 16                   Weedle       Bug  Poison    195  40      35       30
# 17                   Kakuna       Bug  Poison    205  45      25       50
# 18                 Beedrill       Bug  Poison    395  65      90       40
# 19    BeedrillMega Beedrill       Bug  Poison    495  65     150       40
# 20                   Pidgey    Normal  Flying    251  40      45       40
# ...

# %%
df2.loc[9:40,['Total','HP']]
# Out:
#     Total  HP
# 9     314  44
# 10    405  59
# 11    530  79
# 12    630  79
# 13    195  45
# 14    205  50
# 15    395  60
# 16    195  40
# 17    205  45
# 18    395  65
# 19    495  65
# 20    251  40
# 21    349  63
# 22    479  83
# 23    579  83
# 24    253  30
# 25    413  55
# 26    262  40
# 27    442  65
# 28    288  35
# 29    438  60
# 30    320  35
# 31    485  60
# 32    300  50
# 33    450  75
# 34    275  55
# 35    365  70
# 36    505  90
# 37    273  46
# 38    365  61
# 39    505  81
# 40    323  70

# %% [markdown]
# ## 任务3：Pandas数据逻辑索引
# 任务要点：逻辑索引https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.where.html
# - 步骤1：读取文件https://cdn.coggle.club/Pokemon.csv
# - 步骤2：筛选出Type 1 为 Grass的数据
# - 步骤3：筛选出Type 1 为 Grass的数据 且 Type 2 为 Poison的数据
# - 步骤4：筛选出HP大于50 或 Speed小于90的数据
# - 步骤5：筛选出Type 1 取值为Grass 或 Fire，且 HP 位于 70 与 90之间，且 Speed以数字8开头的数据

# %%
df3 = pd.read_csv('https://cdn.coggle.club/Pokemon.csv')

# %%
df3[df3['Type 1']=='Grass']
# Out:
#                       Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0                Bulbasaur  Grass    Poison    318   45      49       49
# 1                  Ivysaur  Grass    Poison    405   60      62       63
# 2                 Venusaur  Grass    Poison    525   80      82       83
# 3    VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 48                  Oddish  Grass    Poison    320   45      50       55
# ..                     ...    ...       ...    ...  ...     ...      ...
# 718                Chespin  Grass       NaN    313   56      61       65
# 719              Quilladin  Grass       NaN    405   61      78       95
# 720             Chesnaught  Grass  Fighting    530   88     107      122
# 740                 Skiddo  Grass       NaN    350   66      65       48
# 741                 Gogoat  Grass       NaN    531  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df3[(df3['Type 1']=='Grass')&(df3['Type 2']=='Poison')]
# Out:
#                       Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0                Bulbasaur  Grass  Poison    318   45      49       49
# 1                  Ivysaur  Grass  Poison    405   60      62       63
# 2                 Venusaur  Grass  Poison    525   80      82       83
# 3    VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48                  Oddish  Grass  Poison    320   45      50       55
# 49                   Gloom  Grass  Poison    395   60      65       70
# 50               Vileplume  Grass  Poison    490   75      80       85
# 75              Bellsprout  Grass  Poison    300   50      75       35
# 76              Weepinbell  Grass  Poison    390   65      90       50
# 77              Victreebel  Grass  Poison    490   80     105       65
# 344                Roselia  Grass  Poison    400   50      60       45
# 451                  Budew  Grass  Poison    280   40      30       35
# ...

# %%
df3[(df3['HP']>50) | (df3['Speed']<90)]
# Out:
#                       Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318   45      49       49
# 1                  Ivysaur    Grass  Poison    405   60      62       63
# 2                 Venusaur    Grass  Poison    525   80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625   80     100      123
# 4               Charmander     Fire     NaN    309   39      52       43
# ..                     ...      ...     ...    ...  ...     ...      ...
# 794       Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795                Diancie     Rock   Fairy    600   50     100      150
# 797    HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799              Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# 筛选出Type 1 取值为Grass 或 Fire，且 HP 位于 70 与 90之间，且 Speed以数字8开头的数据

df3[(df3['Type 1'].isin(['Grass','Fire']))&(df3.HP.between(70,90))&(df3.Speed.astype('str').str.startswith('8'))]
# Out:
#                       Name Type 1    Type 2  Total  HP  Attack  Defense  \
# 2                 Venusaur  Grass    Poison    525  80      82       83
# 3    VenusaurMega Venusaur  Grass    Poison    625  80     100      123
# 168               Meganium  Grass       NaN    525  80      82      100
# 278               Blaziken   Fire  Fighting    530  80     120       70
# 298                Shiftry  Grass      Dark    480  90     100       60
# 468                Cherrim  Grass       NaN    450  70      60       70
# 518              Magmortar   Fire       NaN    540  75      95       67
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 168       83      100     80           2      False
# 278      110       70     80           3      False
# 298       90       60     80           3      False
# 468       87       78     85           4      False
# ...

# %% [markdown]
# ## 任务4：Pandas数据分组聚合
# 任务要点：groupby、agg、transform
# - 步骤1：读取文件https://cdn.coggle.club/Pokemon.csv
# - 步骤2：学习groupby分组聚合的使用
# - 步骤3：学习agg分组聚合的使用
# - 步骤4：学习transform的使用
# - 步骤5：使用groupby、agg、transform，统计数据在Type 1分组下 HP的均值

# %%
df4 = pd.read_csv('https://cdn.coggle.club/Pokemon.csv')

# %%
df4.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# 按  'Type 1','Type 2' 分组后，对Total求和

df4.groupby(['Type 1','Type 2'])['Total'].sum()
# Out:
# Type 1  Type 2
# Bug     Electric     791
#         Fighting    1100
#         Fire         910
#         Flying      5873
#         Ghost        236
#                     ...
# Water   Ice         1535
#         Poison      1280
#         Psychic     2405
#         Rock        1715
#         Steel        530
# Name: Total, Length: 136, dtype: int64

# %%
# 用agg方法，统计聚合后多个统计量
df4.groupby(['Type 1','Type 2'])['Total'].agg(['min', 'mean', 'max'])

# 还可以定义一个字典

agg_func ={'Total':['min', 'mean', 'max']}
df4.groupby(['Type 1','Type 2']).agg(agg_func)
# Out:
#                 Total
#                   min        mean  max
# Type 1 Type 2
# Bug    Electric   319  395.500000  472
#        Fighting   500  550.000000  600
#        Fire       360  455.000000  550
#        Flying     244  419.500000  600
#        Ghost      236  236.000000  236
# ...               ...         ...  ...
# Water  Ice        475  511.666667  535
#        Poison     335  426.666667  515
#        Psychic    315  481.000000  590
#        Rock       355  428.750000  495
#        Steel      530  530.000000  530
#
# [136 rows x 3 columns]

# %% [markdown]
# transform的使用场景：
# ![20211214115054](https://cdn.jsdelivr.net/gh/xihuishawpy/PicBad@main/blogs/pictures/20211214115054.png)

# %% [markdown]
# 分析统计出来的数据需要与原始数据加工到一起，但新旧数据的长度是不一样的
# 1. 常规做法是merge；
# 2. 用transform会更方便；

# %%
# merge 

total_hp = df4.groupby(['Type 1'])['HP'].sum().rename('total_hp').reset_index()

df4_1 = df4.merge(total_hp)
df4_1['HP_ratio']=df4_1['HP']/df4_1['total_hp']

df4_1
# Out:
#                         Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                  Bulbasaur   Grass  Poison    318  45      49       49
# 1                    Ivysaur   Grass  Poison    405  60      62       63
# 2                   Venusaur   Grass  Poison    525  80      82       83
# 3      VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4                     Oddish   Grass  Poison    320  45      50       55
# ..                       ...     ...     ...    ...  ..     ...      ...
# 795                   Klefki   Steel   Fairy    470  57      80       91
# 796  TornadusIncarnate Forme  Flying     NaN    580  79     115       70
# 797    TornadusTherian Forme  Flying     NaN    580  79     100       80
# 798                   Noibat  Flying  Dragon    245  40      30       35
# 799                  Noivern  Flying  Dragon    535  85      70       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  total_hp  HP_ratio
# ...

# %%
# transform

df4['HP_ratio']=df4['HP']/df4.groupby(['Type 1'])['HP'].transform('sum')
df4
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  HP_ratio
# ...

# %%
# 在Type 1分组下 HP的均值

df.groupby(['Type 1'])['HP'].agg('mean')
# Out:
# Type 1
# Bug         56.884058
# Dark        66.806452
# Dragon      83.312500
# Electric    59.795455
# Fairy       74.117647
# Fighting    69.851852
# Fire        69.903846
# Flying      70.750000
# Ghost       64.437500
# Grass       67.271429
# Ground      73.781250
# Ice         72.000000
# Normal      77.275510
# Poison      67.250000
# Psychic     70.631579
# Rock        65.363636
# Steel       65.222222
# Water       72.062500
# Name: HP, dtype: float64

# %%
df.groupby(['Type 1'])['HP'].transform('mean')
# Out:
# 0      67.271429
# 1      67.271429
# 2      67.271429
# 3      67.271429
# 4      69.903846
#          ...
# 795    65.363636
# 796    65.363636
# 797    70.631579
# 798    70.631579
# 799    69.903846
# Name: HP, Length: 800, dtype: float64

# %% [markdown]
# ## 任务5：Pandas日期数据处理
# 任务要点：日期处理
# - 步骤1：创建一列dt，dt取值为从1638263656 到 1638283656 的 unix时间
# - 步骤2：将dt列转为datatime格式
# - 步骤3：筛选出dt列中小时为10的行
# - 步骤4：将dt列整体增加8小时的时间

# %%
dt = [d for d in range(1638263656,1638283657)]

dt_df = pd.DataFrame(pd.to_datetime(dt,unit='s'),columns=['dt'])

dt_df.head()
# Out:
#                    dt
# 0 2021-11-30 09:14:16
# 1 2021-11-30 09:14:17
# 2 2021-11-30 09:14:18
# 3 2021-11-30 09:14:19
# 4 2021-11-30 09:14:20

# %%
dt_df[dt_df['dt'].dt.hour==10]
# Out:
#                       dt
# 2744 2021-11-30 10:00:00
# 2745 2021-11-30 10:00:01
# 2746 2021-11-30 10:00:02
# 2747 2021-11-30 10:00:03
# 2748 2021-11-30 10:00:04
# ...                  ...
# 6339 2021-11-30 10:59:55
# 6340 2021-11-30 10:59:56
# 6341 2021-11-30 10:59:57
# 6342 2021-11-30 10:59:58
# 6343 2021-11-30 10:59:59
#
# [3600 rows x 1 columns]

# %%
dt_df['dt_plus8h'] = dt_df['dt']+pd.Timedelta(8,unit='hours')
dt_df
# Out:
#                        dt           dt_plus8h
# 0     2021-12-01 01:14:16 2021-12-01 09:14:16
# 1     2021-12-01 01:14:17 2021-12-01 09:14:17
# 2     2021-12-01 01:14:18 2021-12-01 09:14:18
# 3     2021-12-01 01:14:19 2021-12-01 09:14:19
# 4     2021-12-01 01:14:20 2021-12-01 09:14:20
# ...                   ...                 ...
# 19996 2021-12-01 06:47:32 2021-12-01 14:47:32
# 19997 2021-12-01 06:47:33 2021-12-01 14:47:33
# 19998 2021-12-01 06:47:34 2021-12-01 14:47:34
# 19999 2021-12-01 06:47:35 2021-12-01 14:47:35
# 20000 2021-12-01 06:47:36 2021-12-01 14:47:36
#
# [20001 rows x 2 columns]

# %% [markdown]
# ## 任务6：Pandas缺失值处理
# 任务要点：groupby、agg、transform
# - 步骤1：读取文件https://cdn.coggle.club/Pokemon.csv
# - 步骤2：分析每列的缺失值
# - 步骤3：对每列的缺失值进行填空

# %%
df6 = pd.read_csv('https://cdn.coggle.club/Pokemon.csv')

# Type 2列，缺失386个值
df6.isnull().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df6.fillna('null')
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire    null    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## 任务7：Pandas数据可视化
#
# https://www.cnblogs.com/zhangyafei/p/10518826.html
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
# 任务要点：plot
#
# - 步骤1：读取文件https://cdn.coggle.club/Pokemon.csv
# - 步骤2：统计Type 1分组下HP、Attack、Defense的均值，并进行绘制柱状图
# - 步骤3：将所有样本的HP、Attack绘制散点图

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.style.use("ggplot")   

df7 = pd.read_csv('https://cdn.coggle.club/Pokemon.csv')
df7.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
plt.figure(dpi=300,figsize=(24,8))

plt.subplot(131)
plt.title('HP')
df7.groupby(['Type 1'])['HP'].mean().plot(kind='barh')

plt.subplot(132)
plt.title('Attack')
df7.groupby(['Type 1'])['Attack'].mean().plot(kind='bar')

plt.subplot(133)
plt.title('Defense')
df7.groupby(['Type 1'])['Defense'].mean().plot(kind='bar')

# %%
plt.figure(dpi=300,figsize=(24,8))

df7.plot(x='HP',y='Attack',color='DarkBlue',kind="scatter",alpha=0.5,colorbar=True)

# %% [markdown]
# ## 任务8：Pandas多表合并和聚合
#
# https://blog.csdn.net/jasonzhoujx/article/details/81665558
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
# https://queirozf.com/entries/pandas-dataframes-merge-join-examples
#
# 任务要点：merge、join
#
# - 步骤1：创建如下数据
# - 步骤2：Merge data1 and data2 Using Inner Join
# - 步骤3：Merge data1 and data2 Using Outer Join
# - 步骤4：Merge data1 and data2 Using Left Join
# - 步骤5：Merge data1 and data2 Using Right Join
# - 步骤6：Merge data1 ,data2 and data3 Using Outer Join
# - 步骤7：Merge data1 and data2 based on Index

# %%
data1 = pd.DataFrame({"ID": range(101, 106),
                      "x1": range(1, 6),
                      "x2": ["a", "b", "c", "d", "e"],
                      "x3": range(16, 11, - 1)})

data2 = pd.DataFrame({"ID": range(104, 108),
                      "y1": ["x", "y", "x", "y"],
                      "y2": range(8, 1, - 2)})

data3 = pd.DataFrame({"ID": range(102, 110),
                      "z1": range(10, 18),
                      "z2": ["z", "b", "z", "z", "d", "z", "d", "a"],
                      "z3": range(18, 10, - 1)})

# %%
pd.merge(data1,data2,how='inner')
# Out:
#     ID  x1 x2  x3 y1  y2
# 0  104   4  d  13  x   8
# 1  105   5  e  12  y   6

# %%
pd.merge(data1,data2,how='outer')
# Out:
#     ID   x1   x2    x3   y1   y2
# 0  101  1.0    a  16.0  NaN  NaN
# 1  102  2.0    b  15.0  NaN  NaN
# 2  103  3.0    c  14.0  NaN  NaN
# 3  104  4.0    d  13.0    x  8.0
# 4  105  5.0    e  12.0    y  6.0
# 5  106  NaN  NaN   NaN    x  4.0
# 6  107  NaN  NaN   NaN    y  2.0

# %%
pd.merge(data1,data2,how='left')
# Out:
#     ID  x1 x2  x3   y1   y2
# 0  101   1  a  16  NaN  NaN
# 1  102   2  b  15  NaN  NaN
# 2  103   3  c  14  NaN  NaN
# 3  104   4  d  13    x  8.0
# 4  105   5  e  12    y  6.0

# %%
pd.merge(data1,data2,how='right')
# Out:
#     ID   x1   x2    x3 y1  y2
# 0  104  4.0    d  13.0  x   8
# 1  105  5.0    e  12.0  y   6
# 2  106  NaN  NaN   NaN  x   4
# 3  107  NaN  NaN   NaN  y   2

# %%
pd.merge(data1,data2,how='outer').merge(data3,how='outer')
# Out:
#     ID   x1   x2    x3   y1   y2    z1   z2    z3
# 0  101  1.0    a  16.0  NaN  NaN   NaN  NaN   NaN
# 1  102  2.0    b  15.0  NaN  NaN  10.0    z  18.0
# 2  103  3.0    c  14.0  NaN  NaN  11.0    b  17.0
# 3  104  4.0    d  13.0    x  8.0  12.0    z  16.0
# 4  105  5.0    e  12.0    y  6.0  13.0    z  15.0
# 5  106  NaN  NaN   NaN    x  4.0  14.0    d  14.0
# 6  107  NaN  NaN   NaN    y  2.0  15.0    z  13.0
# 7  108  NaN  NaN   NaN  NaN  NaN  16.0    d  12.0
# 8  109  NaN  NaN   NaN  NaN  NaN  17.0    a  11.0

# %%
pd.merge(data1,data2,left_index=True,right_index=True)
# Out:
#    ID_x  x1 x2  x3  ID_y y1  y2
# 0   101   1  a  16   104  x   8
# 1   102   2  b  15   105  y   6
# 2   103   3  c  14   106  x   4
# 3   104   4  d  13   107  y   2

# %% [markdown]
# ## 任务9：Pandas透视表和交叉表操作
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html
#
# ![20211226121037](https://cdn.jsdelivr.net/gh/xihuishawpy/PicBad@main/blogs/pictures/20211226121037.png)
#
# - 步骤1：读取文件https://cdn.coggle.club/Pokemon.csv
# - 步骤2：统计Type 1和Type 2分组下HP,Attack,Defense的均值
# - 步骤3：统计Type 1为index，Type 2取值为不同列的情况下，Attack的均值

# %%
df9 = pd.read_csv('https://cdn.coggle.club/Pokemon.csv')

# %%
df9.groupby(['Type 1','Type 2'])['HP','Attack','Defense'].mean()
# Out:
# <ipython-input-20-068d61603fd4>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df9.groupby(['Type 1','Type 2'])['HP','Attack','Defense'].mean()
#                         HP      Attack     Defense
# Type 1 Type 2
# Bug    Electric  60.000000   62.000000   55.000000
#        Fighting  80.000000  155.000000   95.000000
#        Fire      70.000000   72.500000   60.000000
#        Flying    63.000000   70.142857   61.571429
#        Ghost      1.000000   90.000000   45.000000
# ...                    ...         ...         ...
# Water  Ice       90.000000   83.333333  113.333333
#        Poison    61.666667   68.333333   58.333333
#        Psychic   87.000000   73.000000  104.000000
#        Rock      70.750000   82.750000  112.750000
#        Steel     84.000000   86.000000   88.000000
#
# [136 rows x 3 columns]

# %%
df9.pivot_table(index=['Type 1'],columns=['Type 2'],values=['Attack'],aggfunc=np.mean)
# Out:
#          Attack                                                      \
# Type 2      Bug        Dark Dragon Electric       Fairy    Fighting
# Type 1
# Bug         NaN         NaN    NaN     62.0         NaN  155.000000
# Dark        NaN         NaN   85.0      NaN         NaN   82.500000
# Dragon      NaN         NaN    NaN    150.0  110.000000         NaN
# Electric    NaN         NaN   95.0      NaN   58.000000         NaN
# Fairy       NaN         NaN    NaN      NaN         NaN         NaN
# Fighting    NaN  124.000000    NaN      NaN         NaN         NaN
# Fire        NaN         NaN  130.0      NaN         NaN  109.000000
# Flying      NaN         NaN   50.0      NaN         NaN         NaN
# Ghost       NaN   92.000000  110.0      NaN         NaN         NaN
# Grass       NaN   95.000000  110.0      NaN   47.000000  109.000000
# Ground      NaN   90.333333   85.0     66.0         NaN         NaN
# Ice         NaN         NaN    NaN      NaN         NaN         NaN
# ...

# %% [markdown]
# 1. pivot：无法聚合，只能简单重塑，如果存在重复数据将会报错；常用于处理非数字数据。
# 2. pivot_table：可以聚合，正好弥补 pivot 的缺陷。

# %% [markdown]
# ## 任务10：Pandas性能优化
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/enhancingperf.html
#
# https://realpython.com/fast-flexible-pandas/
#
# - 步骤1：创建如下数据
# - 步骤2：使用iloc遍历数据集，并记录下时间。
# - 步骤3：使用itertuples和iterrows 遍历数据集，并记录下时间。
# - 步骤4：使用cython和ndarray完成数据遍历，并统计统计下x1分组下x2的均值。

# %%
data = pd.DataFrame({"x1": list(range(1000, 2000))*1000,
                     "x2": list(range(1000))*1000})

# %%
# %timeit
